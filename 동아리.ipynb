# %%
study_list=["korean","math","english","science","social studies"]
slice_list = study_list[1:4]
slice_list
# Out:
# ['math', 'english', 'science']

# %%
slice_list = study_list[-3:]
slice_list
# Out:
# ['english', 'science', 'social studies']

# %%
study_list=["korean","math","english","science","social studies"]
slice_list = study_list[::2]
slice_list
# Out:
# ['korean', 'english', 'social studies']

# %%
study_list.reverse()
study_list
# Out:
# ['social studies', 'science', 'english', 'math', 'korean']

# %%
study_list=["korean","math","english","science","social studies"]
study_list.append('history')
study_list
# Out:
# ['korean', 'math', 'english', 'science', 'social studies', 'history']

# %%
X, "10 + 12.5"출력
O
O
X, join은 합치는거 아닌가?
X, 순차적 실행 아닌가?
